# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
import pandas as pd
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException

# %% [markdown]
# Login to your Instagram Handle
# Submit with sample username and password

# %%
driver=webdriver.Chrome(executable_path="C:\webdriver\chromedriver")

# %%
driver.get("https://www.instagram.com/")

# %%
inpt=driver.find_element_by_tag_name("input")

# %%
inpt.send_keys("kushal.hu")

# %%
pa=driver.find_element_by_name("password")

# %%
pa.send_keys("power1234@")

# %%
pa.submit()

# %%
#driver.page_source

# %% [markdown]
# Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
# Note : Make sure to avoid printing hashtags

# %%
search=driver.find_element_by_xpath("//div[@class='LWmhU _0aCwM']/input")

# %%
search.send_keys("food")

# %%
allfoods=driver.find_elements_by_xpath("//div[@class='_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ']")

# %%
#allfoods

# %%
for e in allfoods:
    stri=e.get_attribute('innerHTML')
    if stri.startswith('#') or stri.startswith('_'):
        continue
    else:
        print(stri)
# Out:
# foodistamysuru
# mysurufoodie
# mysurufood
# mysuru_street_foodies
# foodloversindia
# foodstorieswithus
# food
# bangalore_food_girl
# yourfoodlab
# foodtalk.mysore
# mysorefoodiesparadise
# sailusfood
# mysoreblogger
# food.and.more__
# foodiesfeature
# mysore_food_guide
# food_bang_theory_
# mysore_foodaholic
# siri_chaitanya_food_product_s
# food_from_karnataka
# foodbheema
# foodholic_memychefi
# food_.trails
# foodies_spot_
# foodys
# kovai_foodie
# yogi_food_stories
# mysuru_foodguru
# foodi.buddy
# food_gasmicc
# ndtv_food
# satshyaa
# foodie_kannadathi
# foody.monk
# foodygrams_karnataka
# funz_foodie
# foodrush.recipe
# foodie_incarnate
# foodbeast
# village_food_factory_official
# foodie_family6
# karnataka_food_works
# food__crushhh___
# healthyfoodindia
# Central Food Technological Research Institute
# srinidhi_hebbur
# blrfood_hunt
# food_meets_you
# Green Food Court
# dr.fooditude

# %% [markdown]
# Searching and Opening a profile using
# Open profile of “So Delhi”

# %%
search=driver.find_element_by_xpath("//div[@class='LWmhU _0aCwM']/input")

# %%
search.send_keys("So Delhi")
time.sleep(5)

# %%
delhi=driver.find_element_by_xpath("//div[@class='_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ']")

# %%
#delhi

# %%
delhi.get_attribute('outerHTML')
# Out:
# '<div class="_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ">sodelhi</div>'

# %%
delhi.click() # HERE THE PROFILW WILL BE OPENED

# %%
Follow/Unfollow given handle - 
Open the Instagram Handle of “So Delhi”
Start following it. Print a message if you are already following
After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
#NOW DUE TO THE CODE OF delhi.click() , That instagram handle has been opened

# %%
btn=driver.find_element_by_xpath("//button[@class='_5f5mN       jIbKX  _6VtSN     yZn4P   ']")

# %%
def tryfollow(btn):
    if btn.is_selected() is True:
        print('Already Followd')
    else:
        btn.click()
        print('Now Followed')

# %%
tryfollow(btn)
# Out:
# Now Followed

# %%
# NOW WE HAVE TO UNFOLLOW

# %%
def unfollow(btn):
    #following=driver.find_element_by_xpath("//span[@class='glyphsSpriteFriend_Follow u-__7']")
    #following.click()
    try:
        if btn.click():
            pass     # THERE WILL BE NO FOLLOW BUTTON
    except StaleElementReferenceException as e:
        following=driver.find_element_by_xpath("//span[@class='glyphsSpriteFriend_Follow u-__7']")
        following.click()
        unfollow=driver.find_element_by_xpath("//button[@class='aOOlW -Cab_   ']")
        unfollow.click()
        print('NOW I HAVE UNFOLLOWED IT')

# %%
unfollow(btn)
# Out:
# NOW I HAVE UNFOLLOWED IT

# %% [markdown]
# Like/Unlike posts
# Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.
# Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
def searchh(text):
    sear=driver.find_element_by_xpath("//div[@class='LWmhU _0aCwM']/input")
    sear.send_keys(text)
    time.sleep(3)
    dilse=driver.find_element_by_xpath("//div[@class='_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ']")
    dilse.click()
searchh("dilsefoodie")

# %% [markdown]
# Like/Unlike posts
# Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.
# Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
#THIS WILL LIKE THE PICTURES WHICH ARE UNLIKED AND UNLIKE THE PICTURE WHICH ARE LIKED
count=0
while True:
    try:
        driver.execute_script('window.scrollBy(0,600);')
        yess=driver.find_elements_by_xpath("//div[@class='_9AhH0']")
        print(yess[count].get_attribute('outerHTML'),count)
        yess[count].click()
        #print(yess[count].get_attribute('outerHTML'))
        time.sleep(3)
        if count==15:
            close=driver.find_element_by_xpath("//div[@class='                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG']/button")
            close.click()
            break
        #print(yess[count]).get_attribute('innerHTML')
        likes=driver.find_element_by_xpath("//section[contains(@class,'ltpMr  Slqrh')]/span/button")
        likes.click()
        time.sleep(3)
        close=driver.find_element_by_xpath("//div[@class='                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG']/button")
        close.click()
        time.sleep(3)
        count=count+1
    except IndexError:
        break

# %%
# NOW PRINTING THE MESSAGE IF IT IS ALREADY LIKED

# %%
#THIS WILL LIKE THE PICTURES WHICH ARE UNLIKED AND LIKED PICTURE WILL NOT DO ANYTHING
count=0
while True:
    try:
        driver.execute_script('window.scrollBy(0,500);')
        #time.sleep(2)
        yess=driver.find_elements_by_xpath("//div[@class='_9AhH0']")
        #print(yess[count].get_attribute('outerHTML'),count)
        time.sleep(7)
        yess[count].click()
        #print(yess[count].get_attribute('outerHTML'))
        time.sleep(8)
        if count==31:
            likes=driver.find_element_by_xpath("//section[contains(@class,'ltpMr  Slqrh')]/span/button")
            vibha=driver.find_element_by_xpath("//div[@class='QBdPU ']/span")
            vibha=vibha.get_attribute('innerHTML')
            if vibha[17:21]=='Like':
                likes.click()
                print('Now you have liked the post',count)
                time.sleep(8)
            else:
                print('You have already Liked the post',count)
            close=driver.find_element_by_xpath("//div[@class='                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG']/button")
            close.click()
            break
        #print(yess[count]).get_attribute('innerHTML')
        likes=driver.find_element_by_xpath("//section[contains(@class,'ltpMr  Slqrh')]/span/button")
        vibha=driver.find_element_by_xpath("//div[@class='QBdPU ']/span")
        vibha=vibha.get_attribute('innerHTML')
        
        if str(vibha[17:21])=='Like':
            #print(vibha)
            likes.click()
            print('Now you have liked the post',count)
            time.sleep(8)
        else:
            print('You have already Liked the post',count)
        #likes.click()
        #time.sleep(7)
        close=driver.find_element_by_xpath("//div[@class='                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG']/button")
        close.click()
        time.sleep(8)
        count=count+1
    except IndexError:
        break
# Out:
# Now you have liked the post 0
# You have already Liked the post 1
# Now you have liked the post 2
# You have already Liked the post 3
# Now you have liked the post 4
# You have already Liked the post 5
# You have already Liked the post 6
# Now you have liked the post 7
# You have already Liked the post 8
# Now you have liked the post 9
# Now you have liked the post 10
# Now you have liked the post 11
# You have already Liked the post 12
# Now you have liked the post 13
# You have already Liked the post 14
# Now you have liked the post 15
# Now you have liked the post 16
# Now you have liked the post 17
# Now you have liked the post 18
# Now you have liked the post 19
# You have already Liked the post 20
# You have already Liked the post 21
# Now you have liked the post 22
# You have already Liked the post 23
# You have already Liked the post 24
# You have already Liked the post 25
# You have already Liked the post 26
# Now you have liked the post 27
# Now you have liked the post 28
# ...

# %%
#THIS WILL LIKE THE PICTURES WHICH ARE UNLIKED AND LIKED PICTURE WILL NOT DO ANYTHING
count=0
while True:
    try:
        driver.execute_script('window.scrollBy(0,500);')
        time.sleep(1)
        yess=driver.find_elements_by_xpath("//div[@class='_9AhH0']")
        #print(yess[count].get_attribute('outerHTML'),count)
        time.sleep(13)
        yess[count].click()
        #print(yess[count].get_attribute('outerHTML'))
        time.sleep(5)
        if count==31:
            likes=driver.find_element_by_xpath("//section[contains(@class,'ltpMr  Slqrh')]/span/button")
            vibha=driver.find_element_by_xpath("//div[@class='QBdPU ']/span")
            vibha=vibha.get_attribute('innerHTML')
            if vibha[17:23]=='Unlike':
                likes.click()
                print('Now you have Unliked the post',count)
                time.sleep(8)
            else:
                print('You have already UnLiked the post',count)
            close=driver.find_element_by_xpath("//div[@class='                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG']/button")
            close.click()
            break
        #print(yess[count]).get_attribute('innerHTML')
        likes=driver.find_element_by_xpath("//section[contains(@class,'ltpMr  Slqrh')]/span/button")
        vibha=driver.find_element_by_xpath("//div[@class='QBdPU ']/span")
        vibha=vibha.get_attribute('innerHTML')
        
        if str(vibha[17:23])=='Unlike':
            #print(vibha)
            likes.click()
            print('Now you have Unliked the post',count)
            time.sleep(8)
        else:
            print('You have already UnLiked the post',count)
        #likes.click()
        #time.sleep(7)
        close=driver.find_element_by_xpath("//div[@class='                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG']/button")
        close.click()
        time.sleep(8)
        count=count+1
    except IndexError:
        break
# Out:
# Now you have Unliked the post 0
# You have already UnLiked the post 1
# Now you have Unliked the post 2
# You have already UnLiked the post 3
# Now you have Unliked the post 4
# You have already UnLiked the post 5
# Now you have Unliked the post 6
# You have already UnLiked the post 7
# Now you have Unliked the post 8
# You have already UnLiked the post 9
# Now you have Unliked the post 10
# You have already UnLiked the post 11
# Now you have Unliked the post 12
# You have already UnLiked the post 13
# Now you have Unliked the post 14
# You have already UnLiked the post 15
# Now you have Unliked the post 16
# You have already UnLiked the post 17
# You have already UnLiked the post 18
# You have already UnLiked the post 19
# You have already UnLiked the post 20
# Now you have Unliked the post 21
# Now you have Unliked the post 22
# Now you have Unliked the post 23
# You have already UnLiked the post 24
# Now you have Unliked the post 25
# You have already UnLiked the post 26
# ...

# %% [markdown]
# Extract list of followers
# Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.
# Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %%
# THIS WILL GIVE YOU THE LIST OF 500 FOLLOWERS OF 'foodtalkindia'
def searchh(text):
    sear=driver.find_element_by_xpath("//div[@class='LWmhU _0aCwM']/input")
    sear.send_keys(text)
    time.sleep(3)
    dilse=driver.find_element_by_xpath("//div[@class='_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ']")
    dilse.click()
searchh("foodtalkindia")

# %%
follow=driver.find_element_by_xpath("//a[@class='-nal3 ']")

# %%
follow.click()

# %%
count=0
while True:
    try:
        followers=driver.find_elements_by_xpath("//div[@class='wFPL8 ']")
        time.sleep(3)
        driver.execute_script('window.scrollBy(0,500);')
        time.sleep(3)
        print(followers[count].text)
        count=count+1
        if count==501:
            break
    except IndexError:
        pass
# Out:
# SRASHTI GUPTA
# Divya Jain
# snigdha
# bongsistersphotography
# Ishani Nisha
# Raman Sekhon
# Food And Beverages🍕
# Arohi Chaubey
# Melissa Elizondo
# Nishchita Raj
# Dead trigger 🔥
# Crunchy Mojo
# Priyanka Bhattacharya
# BANNI MAKEUP ARTIST ✨🧿
# mayank_420vv
# 1M
# Keyur Prajapati
# pritam s naik
# Proud Indians Foundation™
# अंशुल दबंग सरकार
# ꧁ ☬☆🔥 𝕯𝖆𝖛𝖎𝖉 𝕾𝖍𝖆𝖗𝖒𝖆 𝕭𝖆𝖆𝖌𝖍𝖎 🔥☬☆꧂
# NISHAGOGIA
# հíʍíӀ ԹɑԵҽӀ
# ❤️__love__story__❤️
# 😉😇😋😛😎𝕯𝖆𝖛𝖎𝖉 𝖙𝖆𝖐𝖗𝖎😎😏😛
# Harsh Vardhan 👑
# The Belléy High
# Gitika (M) A
# ألينا شيخ🧚‍♀️
# Fooljhadi
# 👑😈paras___vishwakrma😈👑
# khilti
# Yavnika Sood 🧿
# Pasta la vista
# Yashshri Deshmukh
# Aditi Chhetri
# Chandan Kumar
# S_Jaiswal
# Rajesh Kaushik
# PEPPERZ LUCKNOW-KANPUR HIGHWAY
# 8888
# Dilli Biryani
# B⭐️
# Foodingle
# Rok Sa Banjara
# Jayshree Dutta
# Binge N Explore | Mumbai
# Naisha Tiwari
# ruchi
# Tarun Modgil
# The Table Treat
# 🔻Sapphire🔺️
# harun rshid
# Table Lust | Food Blog
# Kaajal Kapoor
# Chef Sunil Ghai
# Pallavi Gupta
# Vyshak
# ...

# %%
def searchh(text):
    sear=driver.find_element_by_xpath("//div[@class='LWmhU _0aCwM']/input")
    sear.send_keys(text)
    time.sleep(3)
    dilse=driver.find_element_by_xpath("//div[@class='_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ']")
    dilse.click()
searchh("sodelhi")

# %%
follow.click()

# %%
follow=driver.find_element_by_xpath("//a[@class='-nal3 ']")

# %%
def follow():
    
    for i in range(50):
        current_height= driver.execute_script('return document.getElementsByClassName("isgrP")[0].scrollHeight;')
        driver.execute_script('document.getElementsByClassName("isgrP")[0].scrollTo(0, arguments[0]);',current_height) 
        time.sleep(1)
    time.sleep(5)
    count=0

follow()

# %%
def jai(count):
    count=0
    allfollow=driver.find_elements_by_xpath("//div[@class='wFPL8 ']")
    for e in allfollow:
        print(e.text)
        count=count+1
        if count==500:
            break
    return
jai(0)
# Out:
# Sneha
# SHAGUN 🔥
#
# 🦋Khushi Tikla
# Bhavnayen
# Sachin prakash Singh
# nirbhay
#
# Saiyam
# Aanchal Maheshwari
# Madhav kumra
# Sumar
# Shivam Jeadia 🇮🇳
# Story of every delhiite
# The Sweet Escape
# Pritha Mukherjee
# Arvinder Singh Multani
# Siddhi
# Preetti Patil
# Arsha Shaheen
# Banu Pramila
# Vanshika
# Pritika Aman
# pooja
# Claude
# Chirag Manu
# Anisha Tanwani
# Aman Kashyap
# Priya sadh
# Rahman Zaman
#
# RUDRAVEER SINGH
# manisha singh
# Prerna Kansal
# Ayan Talwar
# 𝓢𝓪𝓲𝓼𝓱𝓪 🤍
# 𝓝𝓮𝓮𝓻𝓪𝓳 𝓝𝓮𝓰𝓲 🧿
# Neha
# DeV
# Lokesh Sharma
# Preeti Thareja
# Sadaf Shoeb
# kapil balayan
# Amy Vibes
# TheHouseOnTheMove
# Ashita B Chhabra
# Arpit Thakar
# Pragya Verma Makeovers
# Riya
# Naman pandit
# Sonali Shrivastava
# Mohsin Aslam محسن أسلم
# Mayank Tiwari
# The Veggie Trail
# Harshita
# Shanu S
# Chetan Dogra
# Aditya Nair
# Savi Jadhav
# T U B A💎
# Suchita Agrawal
# Kopila Sunar
# Enikeev Ruslan Arturovich
# Seeker
# Sangeet Shyamala
# Choc-Oh! ByAnmol
# रadhika
# ...

# %% [markdown]
# Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
# If You have already seen the story.
# Or The user has no story.
# Or View the story if not yet seen.

# %%
def searchh(text):
    sear=driver.find_element_by_xpath("//div[@class='LWmhU _0aCwM']/input")
    sear.send_keys(text)
    time.sleep(3)
    dilse=driver.find_element_by_xpath("//div[@class='_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ']")
    dilse.click()
searchh("coding.ninjas")

# %%
try:
    
    story=driver.find_element_by_xpath("//div[@class='RR-M- h5uC0']")
    can=driver.find_element_by_xpath("//*[@id='react-root']/section/main/div/header/div/div/canvas")
    height=int(can.get_attribute('height'))
    if height==166:
        story.click()
        print('Now Watching The story')
    else:
        print('Already Watched')
except NoElementSuchException:
    pass
# Out:
# Now Watching The story
